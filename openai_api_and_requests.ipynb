# %%
import requests


cities = ["riyadh", "jeddah", "dammam", "mecca"]


for city in cities:
    r = requests.get(
        f"https://api.midway.tomtom.com/ranking/liveHourly/SAU_{city}",
    )
    print(
    r.text
    )
# Out:
# {"data":[{"JamsDelay":386.4,"TrafficIndexLive":17,"UpdateTime":1719388890001,"TravelTimeLive":68.2759422057581,"TravelTimeHistoric":72.87114196873543,"JamsLength":87.3,"JamsCount":100,"TrafficIndexWeekAgo":5,"UpdateTimeWeekAgo":1718784090001},{"JamsDelay":277.8,"TrafficIndexLive":15,"UpdateTime":1719393390000,"TravelTimeLive":66.7066471499759,"TravelTimeHistoric":73.20076336514994,"JamsLength":76.1,"JamsCount":81,"TrafficIndexWeekAgo":4,"UpdateTimeWeekAgo":1718787690000},{"JamsDelay":141,"TrafficIndexLive":10,"UpdateTime":1719396090000,"TravelTimeLive":64.36888364954916,"TravelTimeHistoric":73.68102705028409,"JamsLength":32.2,"JamsCount":45,"TrafficIndexWeekAgo":3,"UpdateTimeWeekAgo":1718791290000},{"JamsDelay":232.9,"TrafficIndexLive":14,"UpdateTime":1719402390000,"TravelTimeLive":66.44975602367107,"TravelTimeHistoric":77.728463474727,"JamsLength":76.1,"JamsCount":67,"TrafficIndexWeekAgo":3,"UpdateTimeWeekAgo":1718794890000},{"JamsDelay":223.6,"TrafficIndexLive":17,"UpdateTime":1719405090000,"TravelTimeLive":68.32811360189935,"TravelTimeHistoric":81.4589234452474,"JamsLength":96.8,"JamsCount":61,"TrafficIndexWeekAgo":3,"UpdateTimeWeekAgo":1718798490000},{"JamsDelay":680.9,"TrafficIndexLive":29,"UpdateTime":1719409590001,"TravelTimeLive":78.20165810792622,"TravelTimeHistoric":92.44450431560948,"JamsLength":185.4,"JamsCount":166,"TrafficIndexWeekAgo":9,"UpdateTimeWeekAgo":1718804790000},{"JamsDelay":957.3,"TrafficIndexLive":38,"UpdateTime":1719413160000,"TravelTimeLive":85.06635561129832,"TravelTimeHistoric":96.73874667134203,"JamsLength":238.5,"JamsCount":236,"TrafficIndexWeekAgo":13,"UpdateTimeWeekAgo":1718808390001},{"JamsDelay":912.8,"TrafficIndexLive":37,"UpdateTime":1719414060000,"TravelTimeLive":84.80564078867907,"TravelTimeHistoric":96.00914692460873,"JamsLength":209.6,"JamsCount":236,"TrafficIndexWeekAgo":15,"UpdateTimeWeekAgo":1718811090000},{"JamsDelay":713.2,"TrafficIndexLive":29,"UpdateTime":1719417660000,"TravelTimeLive":79.54353286387199,"TravelTimeHistoric":89.12879874008284,"JamsLength":148.4,"JamsCount":188,"TrafficIndexWeekAgo":17,"UpdateTimeWeekAgo":1718815560000},{"JamsDelay":617.3,"TrafficIndexLive":27,"UpdateTime":1719423060000,"TravelTimeLive":78.22332855679754,"TravelTimeHistoric":83.54292030228676,"JamsLength":149.6,"JamsCount":179,"TrafficIndexWeekAgo":21,"UpdateTimeWeekAgo":1718818260000},{"JamsDelay":758.8,"TrafficIndexLive":31,"UpdateTime":1719427590001,"TravelTimeLive":81.34547369915653,"TravelTimeHistoric":82.25722637013507,"JamsLength":161.1,"JamsCount":215,"TrafficIndexWeekAgo":24,"UpdateTimeWeekAgo":1718822790000},{"JamsDelay":640.1,"TrafficIndexLive":29,"UpdateTime":1719428460000,"TravelTimeLive":80.67351097443722,"TravelTimeHistoric":81.41925572315598,"JamsLength":128.4,"JamsCount":178,"TrafficIndexWeekAgo":24,"UpdateTimeWeekAgo":1718823690001},{"JamsDelay":369,"TrafficIndexLive":22,"UpdateTime":1719432090000,"TravelTimeLive":75.26521085914696,"TravelTimeHistoric":75.9371745441122,"JamsLength":69.2,"JamsCount":110,"TrafficIndexWeekAgo":21,"UpdateTimeWeekAgo":1718829990000},{"JamsDelay":261.9,"TrafficIndexLive":18,"UpdateTime":1719435690000,"TravelTimeLive":71.9812695222165,"TravelTimeHistoric":71.62918299342512,"JamsLength":61.1,"JamsCount":74,"TrafficIndexWeekAgo":20,"UpdateTimeWeekAgo":1718830890000},{"JamsDelay":158.2,"TrafficIndexLive":12,"UpdateTime":1719439290000,"TravelTimeLive":67.59760011083036,"TravelTimeHistoric":66.74203984176688,"JamsLength":31.8,"JamsCount":52,"TrafficIndexWeekAgo":14,"UpdateTimeWeekAgo":1718834490000},{"JamsDelay":94.3,"TrafficIndexLive":7,"UpdateTime":1719442890001,"TravelTimeLive":63.315792160633926,"TravelTimeHistoric":64.21442063988086,"JamsLength":15.4,"JamsCount":28,"TrafficIndexWeekAgo":9,"UpdateTimeWeekAgo":1718838090000},{"JamsDelay":73.3,"TrafficIndexLive":3,"UpdateTime":1719446490000,"TravelTimeLive":60.15847635823972,"TravelTimeHistoric":61.51623065342694,"JamsLength":12.5,"JamsCount":24,"TrafficIndexWeekAgo":6,"UpdateTimeWeekAgo":1718841690000},{" ...
# {"data":[{"JamsDelay":54.5,"TrafficIndexLive":5,"UpdateTime":1719392490000,"TravelTimeLive":62.78529591260477,"TravelTimeHistoric":68.23245132682652,"JamsLength":4.5,"JamsCount":17,"TrafficIndexWeekAgo":0,"UpdateTimeWeekAgo":1718787690000},{"JamsDelay":35.1,"TrafficIndexLive":3,"UpdateTime":1719396090000,"TravelTimeLive":61.43473056441565,"TravelTimeHistoric":68.80541233383957,"JamsLength":2.6,"JamsCount":11,"TrafficIndexWeekAgo":0,"UpdateTimeWeekAgo":1718791290000},{"JamsDelay":34.8,"TrafficIndexLive":4,"UpdateTime":1719399690001,"TravelTimeLive":62.47332667484635,"TravelTimeHistoric":69.08718580033518,"JamsLength":2.6,"JamsCount":14,"TrafficIndexWeekAgo":0,"UpdateTimeWeekAgo":1718794890000},{"JamsDelay":20.2,"TrafficIndexLive":4,"UpdateTime":1719403290000,"TravelTimeLive":61.97401123354704,"TravelTimeHistoric":68.49648552349585,"JamsLength":2.7,"JamsCount":7,"TrafficIndexWeekAgo":0,"UpdateTimeWeekAgo":1718798490000},{"JamsDelay":110.5,"TrafficIndexLive":10,"UpdateTime":1719409590001,"TravelTimeLive":66.53418627654536,"TravelTimeHistoric":75.25180170064988,"JamsLength":16,"JamsCount":33,"TrafficIndexWeekAgo":2,"UpdateTimeWeekAgo":1718804790000},{"JamsDelay":264,"TrafficIndexLive":25,"UpdateTime":1719413160000,"TravelTimeLive":76.67316102917437,"TravelTimeHistoric":85.02800282195169,"JamsLength":56.6,"JamsCount":80,"TrafficIndexWeekAgo":7,"UpdateTimeWeekAgo":1718808390001},{"JamsDelay":201,"TrafficIndexLive":25,"UpdateTime":1719414060000,"TravelTimeLive":77.1013880578851,"TravelTimeHistoric":85.57306532813506,"JamsLength":49,"JamsCount":73,"TrafficIndexWeekAgo":10,"UpdateTimeWeekAgo":1718811990000},{"JamsDelay":142.2,"TrafficIndexLive":19,"UpdateTime":1719417660000,"TravelTimeLive":74.3885992965278,"TravelTimeHistoric":82.18336305815252,"JamsLength":21,"JamsCount":49,"TrafficIndexWeekAgo":10,"UpdateTimeWeekAgo":1718812890000},{"JamsDelay":260.9,"TrafficIndexLive":24,"UpdateTime":1719423990000,"TravelTimeLive":77.02753562426705,"TravelTimeHistoric":79.30506179861956,"JamsLength":35.5,"JamsCount":81,"TrafficIndexWeekAgo":19,"UpdateTimeWeekAgo":1718818260000},{"JamsDelay":212.3,"TrafficIndexLive":24,"UpdateTime":1719424860000,"TravelTimeLive":76.64171898816993,"TravelTimeHistoric":79.1920925650686,"JamsLength":29.2,"JamsCount":68,"TrafficIndexWeekAgo":21,"UpdateTimeWeekAgo":1718822790000},{"JamsDelay":283.1,"TrafficIndexLive":28,"UpdateTime":1719430290000,"TravelTimeLive":79.64880799345121,"TravelTimeHistoric":78.32121954562386,"JamsLength":54.6,"JamsCount":95,"TrafficIndexWeekAgo":25,"UpdateTimeWeekAgo":1718825490000},{"JamsDelay":167.2,"TrafficIndexLive":25,"UpdateTime":1719432090000,"TravelTimeLive":77.71828536745915,"TravelTimeHistoric":76.30749370768282,"JamsLength":36.9,"JamsCount":56,"TrafficIndexWeekAgo":25,"UpdateTimeWeekAgo":1718827290000},{"JamsDelay":70.3,"TrafficIndexLive":18,"UpdateTime":1719435690000,"TravelTimeLive":72.48091826325181,"TravelTimeHistoric":71.69136206610662,"JamsLength":12.8,"JamsCount":26,"TrafficIndexWeekAgo":19,"UpdateTimeWeekAgo":1718830890000},{"JamsDelay":47.4,"TrafficIndexLive":10,"UpdateTime":1719439290000,"TravelTimeLive":67.02860342754249,"TravelTimeHistoric":67.08779016109938,"JamsLength":6.9,"JamsCount":15,"TrafficIndexWeekAgo":13,"UpdateTimeWeekAgo":1718834490000},{"JamsDelay":57.7,"TrafficIndexLive":6,"UpdateTime":1719442890001,"TravelTimeLive":63.46725388092573,"TravelTimeHistoric":64.83893941082493,"JamsLength":7,"JamsCount":14,"TrafficIndexWeekAgo":8,"UpdateTimeWeekAgo":1718838090000},{"JamsDelay":25.9,"TrafficIndexLive":4,"UpdateTime":1719446490000,"TravelTimeLive":61.66951122349779,"TravelTimeHistoric":62.87399259448799,"JamsLength":2.7,"JamsCount":8,"TrafficIndexWeekAgo":5,"UpdateTimeWeekAgo":1718841690000},{"JamsDelay":36.1,"TrafficIndexLive":2,"UpdateTime":1719450090000,"TravelTimeLive":59.24638409520547,"TravelTimeHistoric":60.479889836288216,"JamsLength":4.7,"JamsCount":11,"TrafficIndexWeekAgo":3,"UpdateTimeWeekAgo":1718845290000},{"JamsDelay":16.8,"TrafficIndexLive":1,"Updat ...
# {"data":[{"JamsDelay":84.5,"TrafficIndexLive":10,"UpdateTime":1719392490000,"TravelTimeLive":62.658884822764,"TravelTimeHistoric":64.53834794300975,"JamsLength":10.5,"JamsCount":20,"TrafficIndexWeekAgo":6,"UpdateTimeWeekAgo":1718787690000},{"JamsDelay":32.2,"TrafficIndexLive":6,"UpdateTime":1719396090000,"TravelTimeLive":60.477164075845074,"TravelTimeHistoric":64.82922232777412,"JamsLength":3.6,"JamsCount":12,"TrafficIndexWeekAgo":5,"UpdateTimeWeekAgo":1718791290000},{"JamsDelay":20.5,"TrafficIndexLive":5,"UpdateTime":1719399690001,"TravelTimeLive":59.0573141214161,"TravelTimeHistoric":63.77488206264014,"JamsLength":1.8,"JamsCount":8,"TrafficIndexWeekAgo":4,"UpdateTimeWeekAgo":1718796690001},{"JamsDelay":36.1,"TrafficIndexLive":6,"UpdateTime":1719405090000,"TravelTimeLive":58.656084727799815,"TravelTimeHistoric":63.259958307865496,"JamsLength":5.9,"JamsCount":11,"TrafficIndexWeekAgo":4,"UpdateTimeWeekAgo":1718799390000},{"JamsDelay":74.9,"TrafficIndexLive":15,"UpdateTime":1719409590001,"TravelTimeLive":66.23381985279048,"TravelTimeHistoric":71.69628737933456,"JamsLength":24.2,"JamsCount":22,"TrafficIndexWeekAgo":8,"UpdateTimeWeekAgo":1718804790000},{"JamsDelay":108.5,"TrafficIndexLive":18,"UpdateTime":1719412260000,"TravelTimeLive":67.86731622372366,"TravelTimeHistoric":72.89863742165305,"JamsLength":27.2,"JamsCount":37,"TrafficIndexWeekAgo":11,"UpdateTimeWeekAgo":1718807490000},{"JamsDelay":118.8,"TrafficIndexLive":17,"UpdateTime":1719414060000,"TravelTimeLive":68.31670576993224,"TravelTimeHistoric":72.83818504983655,"JamsLength":21,"JamsCount":40,"TrafficIndexWeekAgo":12,"UpdateTimeWeekAgo":1718810190000},{"JamsDelay":114.3,"TrafficIndexLive":16,"UpdateTime":1719420360000,"TravelTimeLive":68.68860857475487,"TravelTimeHistoric":71.6089031565265,"JamsLength":14.9,"JamsCount":36,"TrafficIndexWeekAgo":14,"UpdateTimeWeekAgo":1718815560000},{"JamsDelay":136.7,"TrafficIndexLive":17,"UpdateTime":1719422190000,"TravelTimeLive":69.82705710381133,"TravelTimeHistoric":72.22754902388051,"JamsLength":14.9,"JamsCount":42,"TrafficIndexWeekAgo":16,"UpdateTimeWeekAgo":1718817360001},{"JamsDelay":120.1,"TrafficIndexLive":18,"UpdateTime":1719425790000,"TravelTimeLive":70.94805472848765,"TravelTimeHistoric":72.93781864938369,"JamsLength":10.8,"JamsCount":40,"TrafficIndexWeekAgo":18,"UpdateTimeWeekAgo":1718820990318},{"JamsDelay":96.4,"TrafficIndexLive":17,"UpdateTime":1719428460000,"TravelTimeLive":71.12691723525911,"TravelTimeHistoric":72.58564636738221,"JamsLength":9.5,"JamsCount":35,"TrafficIndexWeekAgo":18,"UpdateTimeWeekAgo":1718823690001},{"JamsDelay":93,"TrafficIndexLive":14,"UpdateTime":1719432090000,"TravelTimeLive":68.81053230323657,"TravelTimeHistoric":69.55529773268522,"JamsLength":9.4,"JamsCount":31,"TrafficIndexWeekAgo":16,"UpdateTimeWeekAgo":1718827290000},{"JamsDelay":36,"TrafficIndexLive":11,"UpdateTime":1719435690000,"TravelTimeLive":65.53648248750682,"TravelTimeHistoric":66.14279765111677,"JamsLength":3.8,"JamsCount":13,"TrafficIndexWeekAgo":13,"UpdateTimeWeekAgo":1718830890000},{"JamsDelay":25.6,"TrafficIndexLive":6,"UpdateTime":1719439290000,"TravelTimeLive":61.382169439129676,"TravelTimeHistoric":62.550684208031555,"JamsLength":2.4,"JamsCount":10,"TrafficIndexWeekAgo":9,"UpdateTimeWeekAgo":1718834490000},{"JamsDelay":26.7,"TrafficIndexLive":5,"UpdateTime":1719442890001,"TravelTimeLive":59.749905855852006,"TravelTimeHistoric":60.65404735078883,"JamsLength":1.9,"JamsCount":6,"TrafficIndexWeekAgo":7,"UpdateTimeWeekAgo":1718838090000},{"JamsDelay":10.3,"TrafficIndexLive":3,"UpdateTime":1719446490000,"TravelTimeLive":57.05204841578977,"TravelTimeHistoric":58.270651620908914,"JamsLength":1.5,"JamsCount":4,"TrafficIndexWeekAgo":6,"UpdateTimeWeekAgo":1718841690000},{"JamsDelay":2.8,"TrafficIndexLive":2,"UpdateTime":1719450090000,"TravelTimeLive":55.307177444898336,"TravelTimeHistoric":56.508103273765606,"JamsLength":1.8,"JamsCount":1,"TrafficIndexWeekAgo":3,"UpdateTimeWeekAgo":1718845290000},{"JamsDelay":20.7,"TrafficIndexLive":0," ...
# {"data":[{"JamsDelay":20.5,"TrafficIndexLive":0,"UpdateTime":1719392490000,"TravelTimeLive":57.521334359371636,"TravelTimeHistoric":61.339528392389134,"JamsLength":1.2,"JamsCount":5,"TrafficIndexWeekAgo":22,"UpdateTimeWeekAgo":1718787690000},{"JamsDelay":14.3,"TrafficIndexLive":0,"UpdateTime":1719396090000,"TravelTimeLive":54.70129333081963,"TravelTimeHistoric":59.64270590982465,"JamsLength":0.7,"JamsCount":5,"TrafficIndexWeekAgo":20,"UpdateTimeWeekAgo":1718793990001},{"JamsDelay":14.1,"TrafficIndexLive":0,"UpdateTime":1719399690001,"TravelTimeLive":56.649819432055146,"TravelTimeHistoric":60.379701924347906,"JamsLength":1.7,"JamsCount":4,"TrafficIndexWeekAgo":26,"UpdateTimeWeekAgo":1718797590000},{"JamsDelay":9.6,"TrafficIndexLive":0,"UpdateTime":1719403290000,"TravelTimeLive":55.78741641677351,"TravelTimeHistoric":59.34951072986284,"JamsLength":0.9,"JamsCount":3,"TrafficIndexWeekAgo":36,"UpdateTimeWeekAgo":1718801190000},{"JamsDelay":20.2,"TrafficIndexLive":1,"UpdateTime":1719409590001,"TravelTimeLive":58.622633393639326,"TravelTimeHistoric":62.593706973459575,"JamsLength":2,"JamsCount":4,"TrafficIndexWeekAgo":37,"UpdateTimeWeekAgo":1718802090000},{"JamsDelay":63.1,"TrafficIndexLive":6,"UpdateTime":1719413160000,"TravelTimeLive":62.643436687777296,"TravelTimeHistoric":66.25537265492473,"JamsLength":9.7,"JamsCount":20,"TrafficIndexWeekAgo":54,"UpdateTimeWeekAgo":1718808390001},{"JamsDelay":100.1,"TrafficIndexLive":8,"UpdateTime":1719415890000,"TravelTimeLive":64.98668341470967,"TravelTimeHistoric":67.31030366500813,"JamsLength":12.7,"JamsCount":27,"TrafficIndexWeekAgo":62,"UpdateTimeWeekAgo":1718811990000},{"JamsDelay":95.4,"TrafficIndexLive":8,"UpdateTime":1719417660000,"TravelTimeLive":65.10972965633388,"TravelTimeHistoric":67.5408110660545,"JamsLength":12.4,"JamsCount":24,"TrafficIndexWeekAgo":61,"UpdateTimeWeekAgo":1718812890000},{"JamsDelay":122.9,"TrafficIndexLive":11,"UpdateTime":1719423990000,"TravelTimeLive":67.29346410844853,"TravelTimeHistoric":69.28100752790365,"JamsLength":15,"JamsCount":36,"TrafficIndexWeekAgo":50,"UpdateTimeWeekAgo":1718818260000},{"JamsDelay":195.4,"TrafficIndexLive":13,"UpdateTime":1719427590001,"TravelTimeLive":69.40063278863249,"TravelTimeHistoric":70.99848517287731,"JamsLength":31.2,"JamsCount":44,"TrafficIndexWeekAgo":45,"UpdateTimeWeekAgo":1718820090000},{"JamsDelay":244.3,"TrafficIndexLive":16,"UpdateTime":1719429390000,"TravelTimeLive":71.20858172878147,"TravelTimeHistoric":71.16970869967192,"JamsLength":28.1,"JamsCount":60,"TrafficIndexWeekAgo":34,"UpdateTimeWeekAgo":1718823690001},{"JamsDelay":128,"TrafficIndexLive":13,"UpdateTime":1719432090000,"TravelTimeLive":69.13168263257667,"TravelTimeHistoric":69.27400680127676,"JamsLength":18.4,"JamsCount":35,"TrafficIndexWeekAgo":30,"UpdateTimeWeekAgo":1718827290000},{"JamsDelay":77.7,"TrafficIndexLive":7,"UpdateTime":1719435690000,"TravelTimeLive":65.7497120506048,"TravelTimeHistoric":67.07951993962693,"JamsLength":10.7,"JamsCount":22,"TrafficIndexWeekAgo":23,"UpdateTimeWeekAgo":1718830890000},{"JamsDelay":55,"TrafficIndexLive":2,"UpdateTime":1719439290000,"TravelTimeLive":62.39559979908761,"TravelTimeHistoric":64.51570117289076,"JamsLength":3.8,"JamsCount":14,"TrafficIndexWeekAgo":17,"UpdateTimeWeekAgo":1718834490000},{"JamsDelay":12.8,"TrafficIndexLive":0,"UpdateTime":1719442890001,"TravelTimeLive":59.14774843956427,"TravelTimeHistoric":62.916190833487825,"JamsLength":0.9,"JamsCount":4,"TrafficIndexWeekAgo":12,"UpdateTimeWeekAgo":1718838090000},{"JamsDelay":10,"TrafficIndexLive":0,"UpdateTime":1719446490000,"TravelTimeLive":57.254058260605746,"TravelTimeHistoric":61.39017313625949,"JamsLength":0.7,"JamsCount":4,"TrafficIndexWeekAgo":7,"UpdateTimeWeekAgo":1718841690000},{"JamsDelay":6.2,"TrafficIndexLive":0,"UpdateTime":1719450090000,"TravelTimeLive":55.31198843783582,"TravelTimeHistoric":59.106485485243454,"JamsLength":1,"JamsCount":3,"TrafficIndexWeekAgo":5,"UpdateTimeWeekAgo":1718845290000},{"JamsDelay":8.4,"TrafficIndexLive":0,"UpdateTi ...

# %%
r.json()['data'][0]
# Out:
# {'JamsDelay': 20.5,
#  'TrafficIndexLive': 0,
#  'UpdateTime': 1719392490000,
#  'TravelTimeLive': 57.521334359371636,
#  'TravelTimeHistoric': 61.339528392389134,
#  'JamsLength': 1.2,
#  'JamsCount': 5,
#  'TrafficIndexWeekAgo': 22,
#  'UpdateTimeWeekAgo': 1718787690000}

# %%
import os
from openai import OpenAI


api_key = os.getenv('OPENAI_API_KEY')


client = OpenAI()

# %% [markdown]
# # Basic Completion Calls

# %%
chat_completion = client.chat.completions.create(
    
    messages=[
        {
            "role": "user",
            "content": "Say this is a test",
        },
    ],
    model="gpt-4",
)

# %%
chat_completion.choices[0].message.content
# Out:
# 'This is a test.'

# %% [markdown]
# # Simple Chaining

# %%
messages = []

while True:
    user_message = input("You: ")
    messages.append({"role": "user", "content": user_message})
    print("User:", user_message)

    chat_completion = client.chat.completions.create(
        messages=messages,
        model="gpt-4",
    )

    response = chat_completion.choices[0].message.content
    messages.append({"role": "assistant", "content": response})

    print("Chat:", response)

    break
# Out:
# User: User: What are the top 10 biggest universities in saudi in terms of number of students
# Chat: The top 10 biggest universities in Saudi Arabia in terms of number of students are:
#
# 1. King Abdulaziz University – As one of the largest universities in Saudi Arabia, it has around 200,000 students.
# 2. King Saud University – This university accommodates about 65,000 students.
# 3. Imam Muhammad ibn Saud Islamic University – Approximately 60,000 students attend this university.
# 4. Umm Al-Qura University – This university in Mecca has upwards of 100,000 students.
# 5. King Fahd University of Petroleum & Minerals – About 10,000 students.
# 6. King Faisal University – Approximately 50,000 students is currently studying.
# 7. King Khalid University – This university has a student population of about 70,000.
# 8. Jazan University – It reports around 50,000 students.
# 9. Taibah University – It is attended by approximately 72,000 students.
# 10. Najran University – It also has approximately 40,000 students.
#
# Note: The figures are approximate and might vary slightly. It is always a good idea to check the latest data from the respective university's website or the Ministry of Education Saudi Arabia.

# %% [markdown]
# # JSON Mode

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "Say this is a test in a json",
        },
    ],
    model="gpt-3.5-turbo",
    response_format={"type": "json_object"},
)

chat_completion
# Out:
# ChatCompletion(id='chatcmpl-9gpKs9cmsxjRh4pgTztONcyFyWzDD', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='{"test": "This is a test"}', role='assistant', function_call=None, tool_calls=None))], created=1719994138, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=9, prompt_tokens=15, total_tokens=24))

# %%
print(chat_completion.choices[0].message.content)
# Out:
# {"test": "This is a test"}

# %% [markdown]
# # Passing Images

# %%
response = client.chat.completions.create(
  model="gpt-4-turbo",
  messages=[
    {
      "role": "user",
      "content": [
        {"type": "text", "text": "What’s in this image?"},
        {
          "type": "image_url",
          "image_url": {
            "url": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg",
          },
        },
      ],
    }
  ],
  max_tokens=300,
)

print(response.choices[0].message)
# Out:
# ChatCompletionMessage(content='This image features a long wooden boardwalk extending through a lush green meadow under a vivid blue sky with scattered clouds. The path seems to offer a tranquil walk through the natural scenery, flanked by tall grasses, wild plants, and scattered bushes. The sunlight enhances the vibrant colors of the landscape, creating a peaceful and inviting outdoor environment. The horizon showcases some trees and the open sky, contributing to a sense of openness and natural beauty.', role='assistant', function_call=None, tool_calls=None)

# %%
print(response.choices[0].message.content)
# Out:
# This image features a long wooden boardwalk extending through a lush green meadow under a vivid blue sky with scattered clouds. The path seems to offer a tranquil walk through the natural scenery, flanked by tall grasses, wild plants, and scattered bushes. The sunlight enhances the vibrant colors of the landscape, creating a peaceful and inviting outdoor environment. The horizon showcases some trees and the open sky, contributing to a sense of openness and natural beauty.

# %% [markdown]
# # Image Generation

# %%
response = client.images.generate(
  model="dall-e-3",
  prompt="a white cat",
  size="1024x1024",
  quality="standard",
  n=1,
)

image_url = response.data[0].url

# %%
image_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-JXTV3zaxmcMwiOktU8TPi4f4/user-UYIKdhxtsfSSqBFNBjBICMNq/img-xrAiLWPWD8xNNRQIqzg4v2JP.png?st=2024-07-03T07%3A09%3A29Z&se=2024-07-03T09%3A09%3A29Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-07-02T14%3A52%3A48Z&ske=2024-07-03T14%3A52%3A48Z&sks=b&skv=2023-11-03&sig=xRaohwchwpmCiovPW6qsgZ8rvc0TJP4JW4BoMyRduHk%3D'

# %% [markdown]
# # Audio Model

# %%
from openai import OpenAI
client = OpenAI()

audio_file= open("/path/to/file/audio.mp3", "rb")
transcription = client.audio.transcriptions.create(
  model="whisper-1", 
  file=audio_file
)
print(transcription.text)
